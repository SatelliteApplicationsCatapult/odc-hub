# %%
# Magic + imports
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

CMAP = "Blues"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# set path
import sys
sys.path.append('/home/jovyan/odc-hub/')
# import required modules
import warnings
warnings.filterwarnings('ignore')
import xarray as xr 
import functools as fct
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from functools import reduce 

# import required datacube modules
from utils_sac.interactive_maps import display_map
from utils_sac.notebook_animation_widgets import create_movie_on_np_array
from utils_sac.plotting import plot_availability
from utils_sac.createAOI import create_lat_lon

# %% [markdown]
# # Water Monitoring
#
# Exploiting multi-modal approaches for generating satellite-derived products can offer spatial-temporal advantages of improved completeness of data completedness and accuracy.
#
# ### Water products
#
# Interoperability is explored across three derived water products from `Sentinel 1`, `Sentinel 2` and `Landsat 8`. The classification and initial data-exploration is conducted in separate notebooks listed below:
#
#    - `Landsat 8`
#    The Water Observations From Space(WOFS) algorithm is applied to Landsat8 imagery. WOFS uses a decision tree on surface reflectance features.
#
#
#    - `Sentinel 2`
#    The Water Observations From Space(WOFS) algorithm is applied to Sentinel 2 imagery. While the original WOFS algorithm was trained and calibrated on Landsat 7 imagery, relatively consistent results are expected from a re-application on Sentinel 2 imagery and are tolerated for the purpose of exploring interoperability.
#
#    - `Sentinel 1`
#    A thresholding algorthim takes advantage of linear class separability on vv and vh bands to classify water.

# %% [markdown]
# ### Loading Water Products
#
# Created using the linked scripts above and saved as NetCDF's.

# %%
# Define dataset file paths
DATA_DIR = Path('/home/shared/geo_demos/wofs_testers')

DATASETS = {
    'l8': DATA_DIR / 'l8_wofs_product_VL.nc',
    #'s1': DATA_DIR / 's1_wofs_product_VL.nc',
    's2': DATA_DIR / 's2_wofs_product_VL.nc'
}

# %%
# Load datasets
datasets = {name: xr.open_dataset(path) for name, path in DATASETS.items()}
print('Loaded datasets: {}'.format(', '.join(datasets.keys())))
print(datasets)
merged = fct.reduce(lambda ds_a, ds_b: ds_a.merge(ds_b), datasets.values())
# Out:
# Loaded datasets: l8, s2
# {'l8': <xarray.Dataset>
# Dimensions:  (time: 69, x: 865, y: 588)
# Coordinates:
#   * time     (time) datetime64[ns] 2018-05-02T22:05:46 ... 2019-04-28T21:59:51
#   * y        (y) float64 7.975e+06 7.975e+06 7.975e+06 ... 8.028e+06 8.028e+06
#   * x        (x) float64 6.167e+05 6.168e+05 6.169e+05 ... 6.944e+05 6.945e+05
# Data variables:
#     wofs     (time, y, x) float64 ..., 's2': <xarray.Dataset>
# Dimensions:  (time: 125, x: 865, y: 588)
# Coordinates:
#   * time     (time) datetime64[ns] 2018-08-25T22:29:59 ... 2019-04-29T22:19:49
#   * y        (y) float64 7.975e+06 7.975e+06 7.975e+06 ... 8.028e+06 8.028e+06
#   * x        (x) float64 6.167e+05 6.168e+05 6.169e+05 ... 6.944e+05 6.945e+05
# Data variables:
#     wofs     (time, y, x) float64 ...}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-6e1efb692a89> in <module>
#       3 print('Loaded datasets: {}'.format(', '.join(datasets.keys())))
#       4 print(datasets)
# ----> 5 merged = fct.reduce(lambda ds_a, ds_b: ds_a.merge(ds_b), datasets.values())
#
# <ipython-input-30-6e1efb692a89> in <lambda>(ds_a, ds_b)
#       3 print('Loaded datasets: {}'.format(', '.join(datasets.keys())))
#       4 print(datasets)
# ----> 5 merged = fct.reduce(lambda ds_a, ds_b: ds_a.merge(ds_b), datasets.values())
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/dataset.py in merge(self, other, inplace, overwrite_vars, compat, join)
#    2803         variables, coord_names, dims = dataset_merge_method(
#    2804             self, other, overwrite_vars=overwrite_vars, compat=compat,
# -> 2805             join=join)
#    2806
#    2807         return self._replace_vars_and_dims(variables, coord_names, dims,
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/merge.py in dataset_merge_method(dataset, other, overwrite_vars, compat, join)
#     566         priority_arg = 2
#     567
# --> 568     return merge_core(objs, compat, join, priority_arg=priority_arg)
#     569
#     570
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/merge.py in merge_core(objs, compat, join, priority_arg, explicit_coords, indexes)
#     443
#     444     coerced = coerce_pandas_values(objs)
# --> 445     aligned = deep_align(coerced, join=join, copy=False, indexes=indexes)
#     446     expanded = expand_variable_dicts(aligned)
#     447
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/alignment.py in deep_align(objects, join, copy, indexes, exclude, raise_on_invalid)
#     215
#     216     aligned = align(*targets, join=join, copy=copy, indexes=indexes,
# --> 217                     exclude=exclude)
#     218
#     219     for position, key, aligned_obj in zip(positions, keys, aligned):
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/alignment.py in align(*objects, **kwargs)
#     163             new_obj = obj.copy(deep=copy)
#     164         else:
# --> 165             new_obj = obj.reindex(copy=copy, **valid_indexers)
#     166         new_obj.encoding = obj.encoding
#     167         result.append(new_obj)
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/dataset.py in reindex(self, indexers, method, tolerance, copy, **indexers_kwargs)
#    2033         variables, indexes = alignment.reindex_variables(
#    2034             self.variables, self.sizes, self.indexes, indexers, method,
# -> 2035             tolerance, copy=copy)
#    2036         coord_names = set(self._coord_names)
#    2037         coord_names.update(indexers)
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/alignment.py in reindex_variables(variables, sizes, indexes, indexers, method, tolerance, copy)
#     342                 raise ValueError(
#     343                     'cannot reindex or align along dimension %r because the '
# --> 344                     'index has duplicate values' % dim)
#     345
#     346             int_indexer = get_indexer_nd(index, target, method, tolerance)
#
# ValueError: cannot reindex or align along dimension 'time' because the index has duplicate values

# %% [markdown]
# ## Fiji - Viti Levu

# %%
#latitudes = (-17.841796875, -18.297729492187)
#longitudes = (178.11035156251, 178.83544921876)
#aoi_wkt = "POLYGON((179.71263885499 -16.428680419921, 180.19603729249 -16.428680419921, 180.17406463624 -16.895599365233, 179.63024139406 -16.862640380858, 179.71263885499 -16.428680419921))"
aoi_wkt = "POLYGON((178.11035156251 -17.841796875, 178.83544921876 -17.830810546875, 178.83544921876 -18.297729492187, 178.10485839844 -18.30322265625, 178.11035156251 -17.841796875))"
lat_extents, lon_extents = create_lat_lon(aoi_wkt)
print("Lat:", lat_extents, "\n"
      "Lon:", lon_extents)
display_map(latitude = lat_extents, longitude = lon_extents)

# %% [markdown]
# # Annual Summary Products
#
# Annual products for each of the three sensors L8, S1 and S2. Dispalying the number of observation which are recorded as water on a scale of 0 to 1.

# %%
fig, axes = plt.subplots(1,3, figsize = (20,4))

a = datasets["l8"].mean(dim = "time", skipna = True).wofs
b = datasets["s2"].mean(dim = "time", skipna = True).wofs
#c = datasets["s1"].mean(dim = "time", skipna = True).wofs

a.plot(ax=axes[0], cmap = CMAP)
axes[0].set_title("Landsat-8 Annual Water Composite")

b.plot(ax=axes[1], cmap = CMAP)
axes[1].set_title("Sentinel-2 Annual Water Composite")

#c.plot(ax=axes[2], cmap = CMAP)
#axes[2].set_title("Sentinel-1 Annual Water Composite")

plt.show()
del a
del b
#del c

# %% [markdown]
# # The Individual Sensors

# %% [markdown]
# # Landsat 8

# %%
print("Total number of L8 images used for the annual product = ", len(datasets["l8"].wofs.values))

# %%
plt.figure(figsize = (12,10))
datasets["l8"].mean(dim = "time", skipna = True).wofs.plot(cmap = CMAP)
plt.title("Landsat-8 Annual Water Composite")

# %%
monthly_l8 = datasets["l8"].resample(time = "M").mean(skipna = True)

# %%
monthly_l8.wofs.plot(col='time',col_wrap=4, cmap = CMAP)

# %%
del monthly_l8

# %% [markdown]
# ## Sentinel 2

# %%
print("Total number of S2 images used for the annual product = ", len(datasets["s2"].wofs.values))
# Out:
# Total number of S2 images used for the annual product =  125

# %%
plt.figure(figsize = (12,10))
datasets["s2"].mean(dim = "time", skipna = True).wofs.plot(cmap = CMAP)
plt.title("Sentinel-2 Annual Water Composite")
# Out:
# Text(0.5, 1.0, 'Sentinel-2 Annual Water Composite')

# %%
monthly_s2 = datasets["s2"].resample(time = "M").mean(skipna = True)
monthly_s2.wofs.plot(col='time',col_wrap=4, cmap = CMAP)

# %%
del monthly_s2

# %% [markdown]
# ## Sentinel 1

# %%
print("Total number of S1 images used for the annual product = ", len(datasets["s1"].wofs.values))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-97a24dc26761> in <module>
# ----> 1 print("Total number of S1 images used for the annual product = ", len(datasets["s1"].wofs.values))
#
# KeyError: 's1'

# %%
plt.figure(figsize = (12,10))
datasets["s1"].mean(dim = "time", skipna = True).wofs.plot(cmap = CMAP)
plt.title("Sentinel-1 Annual Water Composite")

# %%
monthly_s1 = datasets["s1"].resample(time = "M").mean(skipna = True)

# %%
monthly_s1.wofs.plot(col='time',col_wrap=4, cmap = CMAP)

# %%
del monthly_s1

# %% [markdown]
# # Merged Time Series - Interoperability

# %%
#created a merged dataset from the three sensors
merged = fct.reduce(lambda ds_a, ds_b: ds_a.merge(ds_b), datasets.values())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-22ec1335c7b6> in <module>
#       1 #created a merged dataset from the three sensors
# ----> 2 merged = fct.reduce(lambda ds_a, ds_b: ds_a.merge(ds_b), datasets.values())
#
# <ipython-input-7-22ec1335c7b6> in <lambda>(ds_a, ds_b)
#       1 #created a merged dataset from the three sensors
# ----> 2 merged = fct.reduce(lambda ds_a, ds_b: ds_a.merge(ds_b), datasets.values())
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/dataset.py in merge(self, other, inplace, overwrite_vars, compat, join)
#    2803         variables, coord_names, dims = dataset_merge_method(
#    2804             self, other, overwrite_vars=overwrite_vars, compat=compat,
# -> 2805             join=join)
#    2806
#    2807         return self._replace_vars_and_dims(variables, coord_names, dims,
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/merge.py in dataset_merge_method(dataset, other, overwrite_vars, compat, join)
#     566         priority_arg = 2
#     567
# --> 568     return merge_core(objs, compat, join, priority_arg=priority_arg)
#     569
#     570
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/merge.py in merge_core(objs, compat, join, priority_arg, explicit_coords, indexes)
#     443
#     444     coerced = coerce_pandas_values(objs)
# --> 445     aligned = deep_align(coerced, join=join, copy=False, indexes=indexes)
#     446     expanded = expand_variable_dicts(aligned)
#     447
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/alignment.py in deep_align(objects, join, copy, indexes, exclude, raise_on_invalid)
#     215
#     216     aligned = align(*targets, join=join, copy=copy, indexes=indexes,
# --> 217                     exclude=exclude)
#     218
#     219     for position, key, aligned_obj in zip(positions, keys, aligned):
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/alignment.py in align(*objects, **kwargs)
#     163             new_obj = obj.copy(deep=copy)
#     164         else:
# --> 165             new_obj = obj.reindex(copy=copy, **valid_indexers)
#     166         new_obj.encoding = obj.encoding
#     167         result.append(new_obj)
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/dataset.py in reindex(self, indexers, method, tolerance, copy, **indexers_kwargs)
#    2033         variables, indexes = alignment.reindex_variables(
#    2034             self.variables, self.sizes, self.indexes, indexers, method,
# -> 2035             tolerance, copy=copy)
#    2036         coord_names = set(self._coord_names)
#    2037         coord_names.update(indexers)
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/alignment.py in reindex_variables(variables, sizes, indexes, indexers, method, tolerance, copy)
#     342                 raise ValueError(
#     343                     'cannot reindex or align along dimension %r because the '
# --> 344                     'index has duplicate values' % dim)
#     345
#     346             int_indexer = get_indexer_nd(index, target, method, tolerance)
#
# ValueError: cannot reindex or align along dimension 'time' because the index has duplicate values

# %%
plt.figure(figsize = (12,10))
merged.mean(dim = "time", skipna = True).wofs.plot(cmap = CMAP)

# %% [markdown]
# ### Monthly Merged Product

# %%
fused_resample = merged.resample(time = "M").mean(skipna = True)
fused_resample.wofs.plot(col='time',col_wrap=4, cmap = CMAP)

# %%
del fused_resample
