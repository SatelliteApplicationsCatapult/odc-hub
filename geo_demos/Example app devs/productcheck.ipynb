# %%
# Magic + imports likely common across all notebooks
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Supress Warning 
import warnings
warnings.filterwarnings('ignore')
# Set reference for util modules
import sys
sys.path.append('/home/jovyan/odc-hub/')
# Generic python
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr 

# Bonus vector manipulation
import pandas as pd
#from pandas import Dataframe
import geopandas as gpd
from shapely import wkt
from datetime import datetime
import datacube

from matplotlib.cm import RdYlGn, Greens

CMAP = "Blues"

# %%
#import datacube utilities
import utils_dcal.data_cube_utilities.data_access_api as dc_api  
from utils_dcal.data_cube_utilities.dc_load import get_product_extents
from utils_dcal.data_cube_utilities.dc_time import dt_to_str
from utils_dcal.data_cube_utilities.dc_display_map import display_map
from utils_dcal.data_cube_utilities.dc_mosaic import ls8_unpack_qa, ls7_unpack_qa 
from utils_dcal.data_cube_utilities.dc_mosaic import create_max_ndvi_mosaic, create_median_mosaic, create_mosaic
from utils_dcal.data_cube_utilities.dc_rgb import rgb
from utils_sac.createAOI import create_lat_lon

# %%
api = dc_api.DataAccessApi()
dc = datacube.Datacube(app='product check')
#create product list
products_info = dc.list_products()

# %%
aoi_wkt = "POLYGON((179.71263885499 -16.428680419921, 180.19603729249 -16.428680419921, 180.17406463624 -16.895599365233, 179.63024139406 -16.862640380858, 179.71263885499 -16.428680419921))"
output_projection = "EPSG:32760"
resolution = (-30, 30)
platform = 'LANDSAT_8'
product = 'ls8_usgs_wofs_scene'

#platform = 'SENTINEL_2'
#product = 's2_esa_sr_granule'

# %%
#get product time range
full_lat, full_lon, min_max_dates = get_product_extents(api, platform, product, output_crs = output_projection, resolution = resolution)

# Print the extents of the combined data.
print("Latitude Extents:", full_lat)
print("Longitude Extents:", full_lon)
print("Time Extents:", list(map(dt_to_str, min_max_dates)))
# Out:
# Latitude Extents: (7804590.0, 8357520.0)
# Longitude Extents: (378870.0, 853500.0)
# Time Extents: ['2013-05-20', '2019-04-10']

# %%
#len(dc.find_datasets('ls8_usgs_wofs_scene'))
len(dc.find_datasets(product='ls8_usgs_wofs_scene'))
# Out:
# 564

# %%
dc.list_measurements()
# Out:
#                                                                             aliases  \
# product             measurement
# ls4_usgs_sr_scene   blue                                         [band_1, sr_band1]
#                     green                                        [band_2, sr_band2]
#                     red                                          [band_3, sr_band3]
#                     nir                                          [band_4, sr_band4]
#                     swir1                                        [band_5, sr_band5]
#                     swir2                                        [band_7, sr_band7]
#                     sr_atmos_opacity                                     [atmos_op]
#                     pixel_qa                                             [pixel_qa]
#                     radsat_qa                                           [radsat_qa]
#                     sr_cloud_qa                                          [pixel_qa]
# ls5_usgs_sr_scene   blue                                         [band_1, sr_band1]
#                     green                                        [band_2, sr_band2]
#                     red                                          [band_3, sr_band3]
#                     nir                                          [band_4, sr_band4]
#                     swir1                                        [band_5, sr_band5]
#                     swir2                                        [band_7, sr_band7]
#                     sr_atmos_opacity                                     [atmos_op]
#                     pixel_qa                                             [pixel_qa]
#                     radsat_qa                                           [radsat_qa]
#                     sr_cloud_qa                                          [pixel_qa]
# ls7_usgs_sr_scene   blue                                         [band_1, sr_band1]
#                     green                                        [band_2, sr_band2]
#                     red                                          [band_3, sr_band3]
#                     nir                                          [band_4, sr_band4]
#                     swir1                                        [band_5, sr_band5]
#                     swir2                                        [band_7, sr_band7]
#                     sr_atmos_opacity                                     [atmos_op]
#                     pixel_qa                                             [pixel_qa]
#                     radsat_qa                                           [radsat_qa]
#                     sr_cloud_qa                                          [cloud_qa]
# ...                                                                             ...
# ls8_usgs_sr_scene   coastal_aerosol                              [band_1, sr_band1]
#                     blue                                         [band_2, sr_band2]
#                     green                                        [band_3, sr_band3]
#                     red                                          [band_4, sr_band4]
#                     nir                                          [band_5, sr_band5]
#                     swir1                                        [band_6, sr_band6]
#                     swir2                                        [band_7, sr_band7]
#                     pixel_qa                                             [pixel_qa]
#                     sr_aerosol                 [sr_aerosol_qa, aerosol_qa, aerosol]
#                     radsat_qa                                           [radsat_qa]
#                     brightness_temperature_1                   [band_10, bt_band10]
#                     brightness_temperature_2                   [band_11, bt_band11]
# ls8_usgs_wofs_scene water                                                       NaN
# s1g_gamma0_scene    vh                                                          NaN
#                     vv                                                          NaN
# s2_esa_sr_granule   aerosol_optical_thickness                        [aot_10m, aot]
#                     coastal_aerosol                                  [b01_60m, b01]
#                     blue                                             [b02_10m, b02]
#                     green                                            [b03_10m, b03]
#                     red                                              [b04_10m, b04]
#                     vegetation_red_edge_1                            [b05_20m, b05]
#                     vegetation_red_edge_2                            [b06_20m, b06]
#                     vegetation_red_edge_3                            [b07_20m, b07]
#                     nir                                              [b08_10m, b08]
#                     water_vapour                                     [b09_60m, b09]
#                     swir_1                                           [b11_20m, b11]
#                     swir_2                                           [b12_20m, b12]
#                     narrow_nir                                       [b8a_20m, b06]
#                     wvp                                              [wvp_10m, wvp]
#                     scene_classification                             [scl_20m, scl]
#
#                                                  dtype  \
# product             measurement
# ls4_usgs_sr_scene   blue                         int16
#                     green                        int16
#                     red                          int16
#                     nir                          int16
#                     swir1                        int16
#                     swir2                        int16
#                     sr_atmos_opacity             uint8
#                     pixel_qa                    uint16
#                     radsat_qa                    uint8
#                     sr_cloud_qa                 uint16
# ls5_usgs_sr_scene   blue                         int16
#                     green                        int16
#                     red                          int16
#                     nir                          int16
#                     swir1                        int16
#                     swir2                        int16
#                     sr_atmos_opacity             uint8
#                     pixel_qa                    uint16
#                     radsat_qa                    uint8
#                     sr_cloud_qa                 uint16
# ls7_usgs_sr_scene   blue                         int16
#                     green                        int16
#                     red                          int16
#                     nir                          int16
#                     swir1                        int16
#                     swir2                        int16
#                     sr_atmos_opacity             uint8
#                     pixel_qa                    uint16
#                     radsat_qa                    uint8
#                     sr_cloud_qa                  uint8
# ...                                                ...
# ls8_usgs_sr_scene   coastal_aerosol              int16
#                     blue                         int16
#                     green                        int16
#                     red                          int16
#                     nir                          int16
#                     swir1                        int16
#                     swir2                        int16
#                     pixel_qa                    uint16
#                     sr_aerosol                   uint8
#                     radsat_qa                   uint16
#                     brightness_temperature_1     int16
#                     brightness_temperature_2     int16
# ls8_usgs_wofs_scene water                        int16
# s1g_gamma0_scene    vh                         float32
#                     vv                         float32
# s2_esa_sr_granule   aerosol_optical_thickness   uint16
#                     coastal_aerosol             uint16
#                     blue                        uint16
#                     green                       uint16
#                     red                         uint16
#                     vegetation_red_edge_1       uint16
#                     vegetation_red_edge_2       uint16
#                     vegetation_red_edge_3       uint16
#                     nir                         uint16
#                     water_vapour                uint16
#                     swir_1                      uint16
#                     swir_2                      uint16
#                     narrow_nir                  uint16
#                     wvp                         uint16
#                     scene_classification         uint8
#
#                                                                                 flags_definition  \
# product             measurement
# ls4_usgs_sr_scene   blue                                                                     NaN
#                     green                                                                    NaN
#                     red                                                                      NaN
#                     nir                                                                      NaN
#                     swir1                                                                    NaN
#                     swir2                                                                    NaN
#                     sr_atmos_opacity                                                         NaN
#                     pixel_qa                   {'snow': {'bits': 4, 'values': {'0': 'no_snow'...
#                     radsat_qa                  {'radsat_qa': {'bits': [0, 1, 2, 3, 4, 5, 6, 7...
#                     sr_cloud_qa                {'snow': {'bits': 4, 'values': {'0': 'no_snow'...
# ls5_usgs_sr_scene   blue                                                                     NaN
#                     green                                                                    NaN
#                     red                                                                      NaN
#                     nir                                                                      NaN
#                     swir1                                                                    NaN
#                     swir2                                                                    NaN
#                     sr_atmos_opacity                                                         NaN
#                     pixel_qa                   {'snow': {'bits': 4, 'values': {'0': 'no_snow'...
#                     radsat_qa                  {'radsat_qa': {'bits': [0, 1, 2, 3, 4, 5, 6, 7...
#                     sr_cloud_qa                {'snow': {'bits': 4, 'values': {'0': 'no_snow'...
# ls7_usgs_sr_scene   blue                                                                     NaN
#                     green                                                                    NaN
#                     red                                                                      NaN
#                     nir                                                                      NaN
#                     swir1                                                                    NaN
#                     swir2                                                                    NaN
#                     sr_atmos_opacity                                                         NaN
#                     pixel_qa                   {'snow': {'bits': 4, 'values': {'0': 'no_snow'...
#                     radsat_qa                  {'radsat_qa': {'bits': [0, 1, 2, 3, 4, 5, 6, 7...
#                     sr_cloud_qa                {'cloud_qa': {'bits': [0, 1, 2, 3, 4, 5, 6, 7]...
# ...                                                                                          ...
# ls8_usgs_sr_scene   coastal_aerosol                                                          NaN
#                     blue                                                                     NaN
#                     green                                                                    NaN
#                     red                                                                      NaN
#                     nir                                                                      NaN
#                     swir1                                                                    NaN
#                     swir2                                                                    NaN
#                     pixel_qa                   {'snow': {'bits': 4, 'values': {'0': 'no_snow'...
#                     sr_aerosol                 {'aerosol_qa': {'bits': [0, 1, 2, 3, 4, 5, 6, ...
#                     radsat_qa                  {'radsat_qa': {'bits': [0, 1, 2, 3, 4, 5, 6, 7...
#                     brightness_temperature_1                                                 NaN
#                     brightness_temperature_2                                                 NaN
# ls8_usgs_wofs_scene water                      {'dry': {'bits': [7, 6, 5, 0], 'values': {'0':...
# s1g_gamma0_scene    vh                                                                       NaN
#                     vv                                                                       NaN
# s2_esa_sr_granule   aerosol_optical_thickness                                                NaN
#                     coastal_aerosol                                                          NaN
#                     blue                                                                     NaN
#                     green                                                                    NaN
#                     red                                                                      NaN
#                     vegetation_red_edge_1                                                    NaN
#                     vegetation_red_edge_2                                                    NaN
#                     vegetation_red_edge_3                                                    NaN
#                     nir                                                                      NaN
#                     water_vapour                                                             NaN
#                     swir_1                                                                   NaN
#                     swir_2                                                                   NaN
#                     narrow_nir                                                               NaN
#                     wvp                                                                      NaN
#                     scene_classification       {'scene_classification': {'bits': [0, 1, 2, 3,...
#
#                                                                     name  \
# product             measurement
# ls4_usgs_sr_scene   blue                                            blue
#                     green                                          green
#                     red                                              red
#                     nir                                              nir
#                     swir1                                          swir1
#                     swir2                                          swir2
#                     sr_atmos_opacity                    sr_atmos_opacity
#                     pixel_qa                                    pixel_qa
#                     radsat_qa                                  radsat_qa
#                     sr_cloud_qa                              sr_cloud_qa
# ls5_usgs_sr_scene   blue                                            blue
#                     green                                          green
#                     red                                              red
#                     nir                                              nir
#                     swir1                                          swir1
#                     swir2                                          swir2
#                     sr_atmos_opacity                    sr_atmos_opacity
#                     pixel_qa                                    pixel_qa
#                     radsat_qa                                  radsat_qa
#                     sr_cloud_qa                              sr_cloud_qa
# ls7_usgs_sr_scene   blue                                            blue
#                     green                                          green
#                     red                                              red
#                     nir                                              nir
#                     swir1                                          swir1
#                     swir2                                          swir2
#                     sr_atmos_opacity                    sr_atmos_opacity
#                     pixel_qa                                    pixel_qa
#                     radsat_qa                                  radsat_qa
#                     sr_cloud_qa                              sr_cloud_qa
# ...                                                                  ...
# ls8_usgs_sr_scene   coastal_aerosol                      coastal_aerosol
#                     blue                                            blue
#                     green                                          green
#                     red                                              red
#                     nir                                              nir
#                     swir1                                          swir1
#                     swir2                                          swir2
#                     pixel_qa                                    pixel_qa
#                     sr_aerosol                                sr_aerosol
#                     radsat_qa                                  radsat_qa
#                     brightness_temperature_1    brightness_temperature_1
#                     brightness_temperature_2    brightness_temperature_2
# ls8_usgs_wofs_scene water                                          water
# s1g_gamma0_scene    vh                                                vh
#                     vv                                                vv
# s2_esa_sr_granule   aerosol_optical_thickness  aerosol_optical_thickness
#                     coastal_aerosol                      coastal_aerosol
#                     blue                                            blue
#                     green                                          green
#                     red                                              red
#                     vegetation_red_edge_1          vegetation_red_edge_1
#                     vegetation_red_edge_2          vegetation_red_edge_2
#                     vegetation_red_edge_3          vegetation_red_edge_3
#                     nir                                              nir
#                     water_vapour                            water_vapour
#                     swir_1                                        swir_1
#                     swir_2                                        swir_2
#                     narrow_nir                                narrow_nir
#                     wvp                                              wvp
#                     scene_classification            scene_classification
#
#                                                nodata        units
# product             measurement
# ls4_usgs_sr_scene   blue                        -9999  reflectance
#                     green                       -9999  reflectance
#                     red                         -9999  reflectance
#                     nir                         -9999  reflectance
#                     swir1                       -9999  reflectance
#                     swir2                       -9999  reflectance
#                     sr_atmos_opacity                0            1
#                     pixel_qa                        1    bit_index
#                     radsat_qa                       1    bit_index
#                     sr_cloud_qa                     1    bit_index
# ls5_usgs_sr_scene   blue                        -9999  reflectance
#                     green                       -9999  reflectance
#                     red                         -9999  reflectance
#                     nir                         -9999  reflectance
#                     swir1                       -9999  reflectance
#                     swir2                       -9999  reflectance
#                     sr_atmos_opacity                0            1
#                     pixel_qa                        1    bit_index
#                     radsat_qa                       1    bit_index
#                     sr_cloud_qa                     1    bit_index
# ls7_usgs_sr_scene   blue                        -9999  reflectance
#                     green                       -9999  reflectance
#                     red                         -9999  reflectance
#                     nir                         -9999  reflectance
#                     swir1                       -9999  reflectance
#                     swir2                       -9999  reflectance
#                     sr_atmos_opacity                0            1
#                     pixel_qa                        1    bit_index
#                     radsat_qa                       1    bit_index
#                     sr_cloud_qa                     0    bit_index
# ...                                               ...          ...
# ls8_usgs_sr_scene   coastal_aerosol             -9999  reflectance
#                     blue                        -9999  reflectance
#                     green                       -9999  reflectance
#                     red                         -9999  reflectance
#                     nir                         -9999  reflectance
#                     swir1                       -9999  reflectance
#                     swir2                       -9999  reflectance
#                     pixel_qa                        1    bit_index
#                     sr_aerosol                      0    bit_index
#                     radsat_qa                       1    bit_index
#                     brightness_temperature_1    -9999  temperature
#                     brightness_temperature_2    -9999  temperature
# ls8_usgs_wofs_scene water                           1            1
# s1g_gamma0_scene    vh                              0           DN
#                     vv                              0           DN
# s2_esa_sr_granule   aerosol_optical_thickness       0  reflectance
#                     coastal_aerosol                 0  reflectance
#                     blue                            0  reflectance
#                     green                           0  reflectance
#                     red                             0  reflectance
#                     vegetation_red_edge_1           0  reflectance
#                     vegetation_red_edge_2           0  reflectance
#                     vegetation_red_edge_3           0  reflectance
#                     nir                             0  reflectance
#                     water_vapour                    0  reflectance
#                     swir_1                          0  reflectance
#                     swir_2                          0  reflectance
#                     narrow_nir                      0  reflectance
#                     wvp                             0  reflectance
#                     scene_classification            0            1
#
# [64 rows x 6 columns]
