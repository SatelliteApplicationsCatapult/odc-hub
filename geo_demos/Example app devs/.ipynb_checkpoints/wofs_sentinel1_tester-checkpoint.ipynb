# %%
# Magic + imports likely common across all notebooks
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Supress Warning 
import warnings
warnings.filterwarnings('ignore')
# Set reference for util modules
import sys
sys.path.append('/home/jovyan/odc-hub/')
# Generic python
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage.filters import uniform_filter
from scipy.ndimage.measurements import variance
from scipy.ndimage.filters import uniform_filter
from scipy.ndimage.measurements import variance

# Bonus vector manipulation
import pandas as pd
import geopandas as gpd
from shapely import wkt
from datetime import datetime
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Sentinel-1 WOFS Product Creation

# %% [markdown]
# ## Config
# Import required DC utils

# %%
import datacube
# DC utilities
from datacube.storage import masking
from utils_dcal.data_cube_utilities.import_export import export_xarray_to_netcdf

# %% [markdown]
# Define aoi via wkt polygon (could be subbed or shapefile)

# %%
aoi_wkt = "POLYGON((178.12 -18.25,178.15 -18.25,178.15 -18.27,178.12 -18.27,178.12 -18.25))"
aoi = gpd.GeoDataFrame(pd.DataFrame({'geoms':[wkt.loads(aoi_wkt)]}), geometry='geoms')

# %%
dc = datacube.Datacube(app="s1na")

# %%
area_json = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "type": "Polygon",
        "coordinates": [
          [
            [
                aoi.bounds.minx.values[0],
                aoi.bounds.maxy.values[0]
            ],
            [
                aoi.bounds.maxx.values[0],
                aoi.bounds.maxy.values[0]
            ],
            [
                aoi.bounds.maxx.values[0],
                aoi.bounds.miny.values[0]
            ],
            [
                aoi.bounds.minx.values[0],
                aoi.bounds.miny.values[0]
            ],
            [
                aoi.bounds.minx.values[0],
                aoi.bounds.maxy.values[0]
            ]
          ]
        ]
      }
    }
  ]
}

# %%
lons, lats = zip(*area_json["features"][0]["geometry"]["coordinates"][0])
lat_extents = (min(lats), max(lats))
lon_extents = (min(lons), max(lons))
print("Lat:", lat_extents, "\n"
      "Lon:", lon_extents)
# Out:
# Lat: (-18.27, -18.25)
# Lon: (178.12, 178.15)

# %% [markdown]
# ## Load Data
# Generic query specs

# %%
time_step = '12M'
query = dict(   latitude = lat_extents,
                longitude = lon_extents,
                output_crs = "EPSG:32760",
                time = (datetime(2018,1,1), datetime(2019,1,1)),
                resolution = (90,90))

# %% [markdown]
# Dataset-specifics

# %%
scenes = dc.load(product="s1g_gamma0_scene",
                 group_by='solar_day',
               **query)

# %%
s1_coverage = masking.mask_invalid_data(scenes)

# %%
s1_coverage_clean = s1_coverage.where(s1_coverage!=0)

# %%
s1_coverage_clean.isel(time = 0).vv.plot();

# %%
s1_coverage_clean.isel(time = 0).vh.plot();

# %%
# lee filter implemnation doesn't consider nan
from utils_sac.clean_mask import lee_filter
# save the nodata mask
nodata_mask = s1_coverage_clean.isnull().to_array().any(axis=0)
# replace nan with 0
s1_coverage_zerofilled = s1_coverage.where(~s1_coverage.isnull(), 0)

# %%
smoothed_vv=s1_coverage_zerofilled.vv.groupby('time').apply(lee_filter, size=7)
smoothed_vh=s1_coverage_zerofilled.vh.groupby('time').apply(lee_filter, size=7)

# %%
smoothed=smoothed_vv.to_dataset(name='vv')
smoothed['vh']=smoothed_vh

# %%
# put nodata back
smoothed=smoothed.where(~nodata_mask)

# %%
smoothed.isel(time=0).vv.plot()

# %% [markdown]
# Replace 0 with nan and negative with a small value

# %%
clean=smoothed.copy()
clean['vv'] =clean.vv.where(~clean.vv.isnull(), 1000)
clean['vh'] =clean.vh.where(~clean.vh.isnull(), 1000)
print("# of negative pixels in vv vh:", (clean.vv<0).sum().values, (clean.vh<0).sum().values)
#visual check
#(clean.vh<0).any(dim='time').plot()
clean['vv'] =clean.vv.where(clean.vv>0, 1e-3)
clean['vh'] =clean.vh.where(clean.vh>0, 1e-4)
clean=clean.where(clean<1000)
# Out:
# # of negative pixels in vv vh: 41184 41184

# %%
# number of valid observations
clean.vh.count(dim='time').plot()

# %% [markdown]
# Add vv+vh, vh/vv

# %%
clean['vv_plus_vh']=clean.vh+clean.vv
clean['vh_over_vv']=clean.vh/clean.vv
print(clean)
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 44, x: 36, y: 26)
# Coordinates:
#   * y           (y) float64 7.98e+06 7.98e+06 7.98e+06 ... 7.982e+06 7.982e+06
#   * x           (x) float64 6.184e+05 6.185e+05 ... 6.215e+05 6.216e+05
#   * time        (time) datetime64[ns] 2018-04-02T17:40:38 ... 2018-12-29T06:40:00
# Data variables:
#     vv          (time, y, x) float32 0.001 0.001 0.001 ... 0.001 0.001 0.001
#     vh          (time, y, x) float32 1e-04 1e-04 1e-04 ... 1e-04 1e-04 1e-04
#     vv_plus_vh  (time, y, x) float32 0.0011 0.0011 0.0011 ... 0.0011 0.0011
#     vh_over_vv  (time, y, x) float32 0.099999994 0.099999994 ... 0.099999994

# %%
# Filter On
# s1_coverage['Observations'] = ((smoothed_vv <= vv_threshold) & (smoothed_vh <= vh_threshold))

# percentage of total of images in a time window that need to be water to include in the output.

# >>>>>>>>>>>>>>>>>>>>>> CHANGE HERE 
threshold = 70

# Don't change these detection parameters
min_vertices = 100
# water settings in sar
vv_threshold = 12
vh_threshold = -15.5

# Filter Off
s1_coverage['wofs'] = ((smoothed["vv"] <= vv_threshold) & (smoothed["vh"] <= vh_threshold))

# %%
chunks = s1_coverage['wofs'].resample(time=time_step).sum('time')
for t in range(0, chunks.time.size):
    layer = chunks.isel(time=t)
    layer_max = layer.max().values
    layer_threshold = (layer_max / 100 ) * threshold
    print(f"{t} t: {layer_threshold} m: {layer_max}")
    print(layer.time.values)
    
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>CHANGE HERE   

# Threshold Images 
#     layer.where(layer > layer_threshold).plot.imshow(figsize=(12*ar,10))
# Full Range Images    
    layer.where(layer_max > layer_threshold).plot.imshow(figsize=(12,10))
    
    plt.title(f"{layer.time.values}_-_{layer_max}_Observation(s)")
    plt.xlabel("Longitude (meters)")
    plt.ylabel("Latitude (meters)")
    #contour = extract_contour(s1_coverage, layer, layer_threshold, min_vertices)
# Coastline Monitoring  
    #save_poly(f"Inland_water_monitoring/Coastline_{t}.geojson", s1_coverage.crs, contour)
# Inland Water Monitoring        
    #plt.savefig(f"Inland_water_monitoring/Inland_{layer.time.values}.jpg")
    plt.show()
# Out:
# 0 t: 3.5 m: 5
# 2018-04-30T00:00:00.000000000
# 1 t: 27.3 m: 39
# 2019-04-30T00:00:00.000000000

# %% [markdown]
# ## Export to file within shared storage
# Define output path

# %%
# Ensure the output directory exists before writing to it.
# !mkdir -p /home/shared/geo_demos/wofs_testers
output_file_name  =  "/home/shared/geo_demos/wofs_testers/s1_wofs_product.nc"

# %% [markdown]
# Correct attributes and add to wofs xarray (for some reason we have 'dc_partual_load' as true....)

# %%
s1_coverage_clean.attrs
# Out:
# OrderedDict([('crs', CRS('EPSG:32760'))])

# %%
dataset_to_output =  s1_coverage_clean.assign_attrs(s1_coverage_clean.attrs)

# %%
dataset_to_output.attrs
# Out:
# OrderedDict([('crs', CRS('EPSG:32760'))])

# %%
#export_xarray_to_netcdf(dataset_to_output, output_file_name)
export_xarray_to_netcdf(dataset_to_output, output_file_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/backends/file_manager.py in acquire(self, needs_lock)
#     166             try:
# --> 167                 file = self._cache[self._key]
#     168             except KeyError:
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      41         with self._lock:
# ---> 42             value = self._cache[key]
#      43             self._cache.move_to_end(key)
#
# KeyError: [<function _open_netcdf4_group at 0x7fcb28d3dae8>, ('/home/shared/geo_demos/wofs_testers/s1_wofs_product.nc', CombinedLock([<unlocked _thread.lock object at 0x7fcb3bea1918>, <SerializableLock: 84e5f101-478d-4d83-bfd3-07a377559cfa>, <SerializableLock: e4474c44-36b0-40bf-8190-a4ccb72bece3>])), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('group', None), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-170-b711ecccecc8> in <module>
#       1 #export_xarray_to_netcdf(dataset_to_output, output_file_name)
# ----> 2 export_xarray_to_netcdf(dataset_to_output, output_file_name)
#
# ~/odc-hub/utils_dcal/data_cube_utilities/import_export.py in export_xarray_to_netcdf(data, path)
#      43             del data.time.attrs['units']
#      44             data.time.encoding['units'] = time_units
# ---> 45     data.to_netcdf(path)
#      46
#      47 def export_slice_to_geotiff(ds, path, x_coord='longitude', y_coord='latitude'):
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/core/dataset.py in to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute)
#    1321                          engine=engine, encoding=encoding,
#    1322                          unlimited_dims=unlimited_dims,
# -> 1323                          compute=compute)
#    1324
#    1325     def to_zarr(self, store=None, mode='w-', synchronizer=None, group=None,
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/backends/api.py in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile)
#     791     target = path_or_file if path_or_file is not None else BytesIO()
#     792     kwargs = dict(autoclose=True) if autoclose else {}
# --> 793     store = store_open(target, mode, format, group, **kwargs)
#     794
#     795     if unlimited_dims is None:
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     350             kwargs=dict(group=group, clobber=clobber, diskless=diskless,
#     351                         persist=persist, format=format))
# --> 352         return cls(manager, lock=lock, autoclose=autoclose)
#     353
#     354     @property
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, lock, autoclose)
#     309
#     310         self._manager = manager
# --> 311         self.format = self.ds.data_model
#     312         self._filename = self.ds.filepath()
#     313         self.is_remote = is_remote_uri(self._filename)
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     354     @property
#     355     def ds(self):
# --> 356         return self._manager.acquire().value
#     357
#     358     def open_store_variable(self, name, var):
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/backends/file_manager.py in acquire(self, needs_lock)
#     171                     kwargs = kwargs.copy()
#     172                     kwargs['mode'] = self._mode
# --> 173                 file = self._opener(*self._args, **kwargs)
#     174                 if self._mode == 'w':
#     175                     # ensure file doesn't get overriden when opened again
#
# /opt/conda/envs/cubeenv/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in _open_netcdf4_group(filename, lock, mode, group, **kwargs)
#     242     import netCDF4 as nc4
#     243
# --> 244     ds = nc4.Dataset(filename, mode=mode, **kwargs)
#     245
#     246     with close_on_error(ds):
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# PermissionError: [Errno 13] Permission denied: b'/home/shared/geo_demos/wofs_testers/s1_wofs_product.nc'

# %%
s1_coverage.wofs.mean(dim = 'time').plot(cmap = "Blues");
